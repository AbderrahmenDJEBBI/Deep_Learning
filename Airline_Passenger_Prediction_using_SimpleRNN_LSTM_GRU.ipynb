# %% [markdown]
# ## Airline Passenger Forecasting using RNN, LSTM & GRU

# %% [markdown]
# In this lab, we will estimate the number of passengers in the coming years by analysing the number of passengers in the past years.

# %%
# # Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
import math

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# This dataset contains how many passengers traveled monthly from 1949 to 1960.
#
#
# **Month: the date in the month is a variable.**
#
#
# **Passengers: estimates the number of passengers per month.**

# %%
# # Import and show dataset
data = pd.read_csv("international-airline-passengers.csv")
print("Shape of Data: ", data.shape)
data.head()
# Out:
# Shape of Data:  (145, 2)
#      Month  \
# 0  1949-01
# 1  1949-02
# 2  1949-03
# 3  1949-04
# 4  1949-05
#
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                              112.0
# 1                                              118.0
# 2                                              132.0
# 3                                              129.0
# 4                                              121.0

# %%
# Plot data
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#        International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# count                                         144.000000
# mean                                          280.298611
# std                                           119.966317
# min                                           104.000000
# 25%                                           180.000000
# 50%                                           265.500000
# 75%                                           360.500000
# max                                           622.000000

# %%
# Drop the row with NaN
data=data.dropna(how='any',axis=0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Month                                                                           144 non-null    object
#  1   International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60  144 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.4+ KB

# %%
# # Create a dataframe with only the number of passengers
df=data.drop('Month', axis=1)
# # Convert the dataframe to a numpy array
df=df.values
print(df[:5])
# Out:
# [[112.]
#  [118.]
#  [132.]
#  [129.]
#  [121.]]

# %%
# Scale the data to make it applicable for RNN
scaler=MinMaxScaler(feature_range=(0,1))
df_scaled=scaler.fit_transform(df)
df_scaled[:5]
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853]])

# %%
# Split data into predictors and outcomes
# predict the number of passengers using by the past 6 months' number of passengers
X = []
y = []
sequence = 6
for i in range(len(df_scaled) - sequence):
    X.append(df_scaled[i:(i + sequence), 0])
    y.append(df_scaled[i + sequence, 0])

X = np.array(X)
y = np.array(y)

# %%
print("Predictors")
print(X[:5])
print("Outcomes")
print(y[:5])
# Out:
# Predictors
# [[0.01544402 0.02702703 0.05405405 0.04826255 0.03281853 0.05984556]
#  [0.02702703 0.05405405 0.04826255 0.03281853 0.05984556 0.08494208]
#  [0.05405405 0.04826255 0.03281853 0.05984556 0.08494208 0.08494208]
#  [0.04826255 0.03281853 0.05984556 0.08494208 0.08494208 0.06177606]
#  [0.03281853 0.05984556 0.08494208 0.08494208 0.06177606 0.02895753]]
# Outcomes
# [0.08494208 0.08494208 0.06177606 0.02895753 0.        ]

# %%
# # Reshape the predictor 
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
X.shape
# Out:
# (138, 6, 1)

# %%
# # Split data into training and test sets 

# # Set the size of training and test data
# # Use 75% of the data for training
train_size = math.ceil(len(X) * 0.75)
test_size = len(X - train_size)

# # Split X and y into training and test sets
X_train = X[:train_size, :]
y_train = y[:train_size]

X_test = X[train_size:len(X),:]
y_test = y[train_size:len(y)]

# %%
# # Show the size of training and test sets
print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test : ", X_test.shape)
print("y_test : ", y_test.shape)
# Out:
# X_train:  (104, 6, 1)
# y_train:  (104,)
# X_test :  (34, 6, 1)
# y_test :  (34,)

# %%
# Simple RNN model
rnn=Sequential()
rnn.add(SimpleRNN(units=32, return_sequences=True, input_shape=(X_train.shape[1],1)))
rnn.add(SimpleRNN(units=32, return_sequences=True))
rnn.add(SimpleRNN(units=32, return_sequences=True))
rnn.add(SimpleRNN(units=32))
rnn.add(Dense(units=1))

# %%
# SimpleRNN summary
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 6, 32)             1088
#
#  simple_rnn_1 (SimpleRNN)    (None, 6, 32)             2080
#
#  simple_rnn_2 (SimpleRNN)    (None, 6, 32)             2080
#
#  simple_rnn_3 (SimpleRNN)    (None, 32)                2080
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 7,361
# Trainable params: 7,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile SimpleRNN model (Adam optimizer, Mean_squared_error loss)
rnn.compile(optimizer='adam', loss='mean_squared_error')

# %%
# LSTM model
lstm=Sequential()
lstm.add(LSTM(units=32, return_sequences=True, input_shape=(X_train.shape[1],1)))
lstm.add(LSTM(units=32, return_sequences=True))
lstm.add(LSTM(units=32, return_sequences=True))
lstm.add(LSTM(units=32))
lstm.add(Dense(units=1))

# %%
# LSTM summary
lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 32)             4352
#
#  lstm_1 (LSTM)               (None, 6, 32)             8320
#
#  lstm_2 (LSTM)               (None, 6, 32)             8320
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 29,345
# Trainable params: 29,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile LSTM model (Adam optimizer, Mean_squared_error loss) 
lstm.compile(optimizer='adam', loss='mean_squared_error')

# %%
# GRU model
gru=Sequential()
gru.add(GRU(units=32, return_sequences=True, input_shape=(X_train.shape[1],1)))
gru.add(GRU(units=32, return_sequences=True))
gru.add(GRU(units=32, return_sequences=True))
gru.add(GRU(units=32))
gru.add(Dense(units=1))

# %%
# GRU summary
gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 6, 32)             3360
#
#  gru_1 (GRU)                 (None, 6, 32)             6336
#
#  gru_2 (GRU)                 (None, 6, 32)             6336
#
#  gru_3 (GRU)                 (None, 32)                6336
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 22,401
# Trainable params: 22,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile GRU model (Adam optimizer, Mean_squared_error loss) 
gru.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Set Early Stopping
#early_stop = EarlyStopping(monitor='val_loss', patience=40)
early_stop = EarlyStopping(monitor='val_loss', patience=40)

# %%
# Fit Simple RNN model (batch=16, epochs=1000)
rnn_history=rnn.fit(X_train, y_train, batch_size=16, epochs=1000, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 2s 53ms/step - loss: 0.0924 - val_loss: 0.1412
# Epoch 2/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0266 - val_loss: 0.0247
# Epoch 3/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0189 - val_loss: 0.0530
# Epoch 4/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0628
# Epoch 5/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0365
# Epoch 6/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0385
# Epoch 7/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0355
# Epoch 8/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0314
# Epoch 9/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0368
# Epoch 10/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0320
# Epoch 11/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0265
# Epoch 12/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0286
# Epoch 13/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0269
# Epoch 14/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0220
# Epoch 15/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0316
# Epoch 16/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0182
# Epoch 17/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0248
# Epoch 18/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0260
# Epoch 19/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0259
# Epoch 20/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0173
# Epoch 21/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0144
# Epoch 22/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0174
# Epoch 23/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0203
# Epoch 24/1000
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0031 - val_loss: 0.0260
# Epoch 25/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0228
# Epoch 26/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0151
# Epoch 27/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0181
# Epoch 28/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0179
# Epoch 29/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0154
# Epoch 30/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0174
# Epoch 31/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0231
# Epoch 32/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0188
# Epoch 33/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0164
# Epoch 34/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0105
# Epoch 35/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0122
# Epoch 36/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0259
# Epoch 37/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0286
# Epoch 38/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0221
# Epoch 39/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0122
# Epoch 40/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0131
# Epoch 41/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0137
# Epoch 42/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0165
# Epoch 43/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0169
# Epoch 44/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0196
# Epoch 45/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0125
# Epoch 46/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0183
# Epoch 47/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0142
# Epoch 48/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 49/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0119
# Epoch 50/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0112
# Epoch 51/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0163
# Epoch 52/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0229
# Epoch 53/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0165
# Epoch 54/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0165
# Epoch 55/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0163
# Epoch 56/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0141
# Epoch 57/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0115
# Epoch 58/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0159
# Epoch 59/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0236
# Epoch 60/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0242
# Epoch 61/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0177
# Epoch 62/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0210
# Epoch 63/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0174
# Epoch 64/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0102
# Epoch 65/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0147
# Epoch 66/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0170
# Epoch 67/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0090
# Epoch 68/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 69/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0158
# Epoch 70/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0145
# Epoch 71/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0146
# Epoch 72/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0177
# Epoch 73/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0136
# Epoch 74/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0157
# Epoch 75/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0170
# Epoch 76/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0129
# Epoch 77/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0196
# Epoch 78/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0198
# Epoch 79/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0153
# Epoch 80/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0156
# Epoch 81/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0129
# Epoch 82/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0116
# Epoch 83/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0209
# Epoch 84/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0148
# Epoch 85/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0121
# Epoch 86/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0101
# Epoch 87/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0148
# Epoch 88/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0161
# Epoch 89/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0198
# Epoch 90/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0250
# Epoch 91/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0151
# Epoch 92/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0202
# Epoch 93/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0184
# Epoch 94/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0155
# Epoch 95/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0186
# Epoch 96/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0147
# Epoch 97/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0115
# Epoch 98/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0189
# Epoch 99/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0156
# Epoch 100/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0080
# Epoch 101/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0151
# Epoch 102/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0166
# Epoch 103/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0247
# Epoch 104/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0228
# Epoch 105/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0178
# Epoch 106/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0186
# Epoch 107/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0116
# Epoch 108/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0121
# Epoch 109/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 110/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0120
# Epoch 111/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0087
# Epoch 112/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0080
# Epoch 113/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0124
# Epoch 114/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0077
# Epoch 115/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0107
# Epoch 116/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0095
# Epoch 117/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0085
# Epoch 118/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 119/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0064
# Epoch 120/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0098
# Epoch 121/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0085
# Epoch 122/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0094
# Epoch 123/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0110
# Epoch 124/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0186
# Epoch 125/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0154
# Epoch 126/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0141
# Epoch 127/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0169
# Epoch 128/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0163
# Epoch 129/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0148
# Epoch 130/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 0.0202
# Epoch 131/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 0.0123
# Epoch 132/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0109
# Epoch 133/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0126
# Epoch 134/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0107
# Epoch 135/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0142
# Epoch 136/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0168
# Epoch 137/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0121
# Epoch 138/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0098
# Epoch 139/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0094
# Epoch 140/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0089
# Epoch 141/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0093
# Epoch 142/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0099
# Epoch 143/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0097
# Epoch 144/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0088
# Epoch 145/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0101
# Epoch 146/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0133
# Epoch 147/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0151
# Epoch 148/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0115
# Epoch 149/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0149
# Epoch 150/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0174
# Epoch 151/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0181
# Epoch 152/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0145
# Epoch 153/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0140
# Epoch 154/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0141
# Epoch 155/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0134
# Epoch 156/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0118
# Epoch 157/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0169
# Epoch 158/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0138
# Epoch 159/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0103

# %%
# Fit LSTM model (batch=16, epochs=1000)
lstm_history=lstm.fit(X_train, y_train, batch_size=16, epochs=1000, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 4s 134ms/step - loss: 0.0760 - val_loss: 0.2866
# Epoch 2/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0341 - val_loss: 0.1023
# Epoch 3/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0207 - val_loss: 0.0685
# Epoch 4/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0185 - val_loss: 0.1018
# Epoch 5/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0167 - val_loss: 0.0906
# Epoch 6/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0133 - val_loss: 0.0448
# Epoch 7/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0116 - val_loss: 0.0457
# Epoch 8/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0104 - val_loss: 0.0441
# Epoch 9/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0407
# Epoch 10/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0406
# Epoch 11/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0099 - val_loss: 0.0435
# Epoch 12/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0096 - val_loss: 0.0379
# Epoch 13/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0424
# Epoch 14/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.0406
# Epoch 15/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0413
# Epoch 16/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0394
# Epoch 17/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0360
# Epoch 18/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0438
# Epoch 19/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0344
# Epoch 20/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0095 - val_loss: 0.0431
# Epoch 21/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 0.0391
# Epoch 22/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0404
# Epoch 23/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0412
# Epoch 24/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0378
# Epoch 25/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0404
# Epoch 26/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0088 - val_loss: 0.0384
# Epoch 27/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0397
# Epoch 28/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0382
# Epoch 29/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0086 - val_loss: 0.0428
# Epoch 30/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0400
# Epoch 31/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0360
# Epoch 32/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0423
# Epoch 33/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0388
# Epoch 34/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0405
# Epoch 35/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0088 - val_loss: 0.0395
# Epoch 36/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0518
# Epoch 37/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0357
# Epoch 38/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0462
# Epoch 39/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0392
# Epoch 40/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0435
# Epoch 41/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0426
# Epoch 42/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 0.0416
# Epoch 43/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0490
# Epoch 44/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0415
# Epoch 45/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0443
# Epoch 46/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0443
# Epoch 47/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0432
# Epoch 48/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0490
# Epoch 49/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.0407
# Epoch 50/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0471
# Epoch 51/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0455
# Epoch 52/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0083 - val_loss: 0.0440
# Epoch 53/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 0.0543
# Epoch 54/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0423
# Epoch 55/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0449
# Epoch 56/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0471
# Epoch 57/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0436
# Epoch 58/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0472
# Epoch 59/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0078 - val_loss: 0.0452

# %%
# Fit GRU model (batch=16, epochs=1000)
gru_history=gru.fit(X_train, y_train, batch_size=16, epochs=1000, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 5s 131ms/step - loss: 0.0489 - val_loss: 0.0755
# Epoch 2/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0234 - val_loss: 0.0547
# Epoch 3/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0145 - val_loss: 0.1000
# Epoch 4/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0133 - val_loss: 0.0539
# Epoch 5/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0364
# Epoch 6/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0411
# Epoch 7/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0311
# Epoch 8/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0352
# Epoch 9/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0317
# Epoch 10/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0338
# Epoch 11/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0380
# Epoch 12/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0308
# Epoch 13/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0331
# Epoch 14/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0306
# Epoch 15/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0340
# Epoch 16/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0291
# Epoch 17/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0074 - val_loss: 0.0334
# Epoch 18/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0315
# Epoch 19/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0295
# Epoch 20/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0323
# Epoch 21/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0267
# Epoch 22/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 0.0300
# Epoch 23/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0276
# Epoch 24/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0299
# Epoch 25/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0267
# Epoch 26/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0276
# Epoch 27/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0257
# Epoch 28/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0061 - val_loss: 0.0265
# Epoch 29/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0256
# Epoch 30/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0263
# Epoch 31/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0233
# Epoch 32/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0057 - val_loss: 0.0213
# Epoch 33/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0243
# Epoch 34/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0051 - val_loss: 0.0176
# Epoch 35/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0222
# Epoch 36/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0157
# Epoch 37/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0208
# Epoch 38/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0152
# Epoch 39/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 0.0219
# Epoch 40/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0135
# Epoch 41/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0040 - val_loss: 0.0229
# Epoch 42/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0137
# Epoch 43/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0041 - val_loss: 0.0135
# Epoch 44/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0148
# Epoch 45/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0117
# Epoch 46/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0133
# Epoch 47/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0157
# Epoch 48/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0123
# Epoch 49/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 50/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0032 - val_loss: 0.0120
# Epoch 51/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0137
# Epoch 52/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0114
# Epoch 53/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0091
# Epoch 54/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0026 - val_loss: 0.0138
# Epoch 55/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0109
# Epoch 56/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0140
# Epoch 57/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0150
# Epoch 58/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0101
# Epoch 59/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0024 - val_loss: 0.0109
# Epoch 60/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0113
# Epoch 61/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0106
# Epoch 62/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0106
# Epoch 63/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0107
# Epoch 64/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0125
# Epoch 65/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0116
# Epoch 66/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0128
# Epoch 67/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0089
# Epoch 68/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0027 - val_loss: 0.0175
# Epoch 69/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0084
# Epoch 70/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0029 - val_loss: 0.0164
# Epoch 71/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0100
# Epoch 72/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0106
# Epoch 73/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0152
# Epoch 74/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0092
# Epoch 75/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0147
# Epoch 76/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0086
# Epoch 77/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0149
# Epoch 78/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0088
# Epoch 79/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0119
# Epoch 80/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0093
# Epoch 81/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0020 - val_loss: 0.0110
# Epoch 82/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0111
# Epoch 83/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0023 - val_loss: 0.0135
# Epoch 84/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0108
# Epoch 85/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0111
# Epoch 86/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0113
# Epoch 87/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0113
# Epoch 88/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0118
# Epoch 89/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0101
# Epoch 90/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 91/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0129
# Epoch 92/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0091
# Epoch 93/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0121
# Epoch 94/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0095
# Epoch 95/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0152
# Epoch 96/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0095
# Epoch 97/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0145
# Epoch 98/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 99/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0115
# Epoch 100/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0102
# Epoch 101/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0110
# Epoch 102/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0112
# Epoch 103/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0117
# Epoch 104/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0102
# Epoch 105/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 106/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0023 - val_loss: 0.0126
# Epoch 107/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0108
# Epoch 108/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0109
# Epoch 109/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0103

# %%
# # Visualize Training History

# # Set subplot subtitles
titles = ['RNN', 'LSTM', 'GRU']

# # Create a list of prediction models
models = [rnn_history, lstm_history, gru_history]
# # Set the plot area
fig, ax = plt.subplots(1, 3, figsize=(16,4), tight_layout=True)  

# # Plot learning history
plt.suptitle('Learning History')
for i in range(0, 3):
    plt.subplot(1, 3, i+1)
    plt.title(titles[i], fontsize=10) 
    plt.plot(models[i].history['loss'], label='loss')
    plt.plot(models[i].history['val_loss'], label='val loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='best')
    plt.ylim([0,0.05])

# %%
# # Make predictions and reverse the predicted value to real number

# # Predict by RNN model
rnn_y_pred=rnn.predict(X_test)
rnn_y_pred=scaler.inverse_transform(rnn_y_pred)

# # Predict by LSTM model
lstm_y_pred=lstm.predict(X_test)
lstm_y_pred=scaler.inverse_transform(lstm_y_pred)

# # Predict by GRU model
gru_y_pred=gru.predict(X_test)
gru_y_pred=scaler.inverse_transform(gru_y_pred)

# # Reverse test data to real number
y_test=y_test.reshape(y_test.shape[0],1)
y_test=scaler.inverse_transform(y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 1s 3ms/step

# %%
# # Visualize Prediction Results

# # Set subplot subtitles
titles = ['RNN', 'LSTM', 'GRU']

# # Create a list of prediction models
models = [rnn_y_pred, lstm_y_pred, gru_y_pred]

# # Set the plot area
fig, ax = plt.subplots(1, 3, figsize=(16,4), tight_layout=True)  

# # Set the title
plt.suptitle('Airline Passenger Forecasting')

# # Create and show subplots
for i in range(0, 3):
        plt.subplot(1, 3,i+1)
        plt.title(titles[i], fontsize=10) 
        plt.plot(y_test, label='N of Passengers')
        plt.plot(models[i], label=titles[i]+' Prediction')
        plt.legend()
        plt.xlabel('Time')
        plt.ylabel('N of Passengers')
